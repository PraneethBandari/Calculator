# %% [markdown]
# <a href="https://colab.research.google.com/github/PraneethBandari/Calculator/blob/main/cfda1q1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
# Out:
# hello

# %%
import pandas as pd

# Read the fixed width file using delim_whitespace
df = pd.read_csv("/content/fdmq1sol (1).txt",delim_whitespace=True)

# Save the DataFrame to a CSV file
df.to_csv("/content/fdmq1sol (1).txt", index=False)

# %%
import matplotlib.pyplot as plt
dataframe = pd.read_csv("/content/fdmq1sol (1).txt")

#Plotting x and Y labels
plt.plot(dataframe.iloc[:,0],dataframe.iloc[:,1])

plt.xlabel( "Nodes")
plt.ylabel( "Temperature")
plt.show()

# %% [markdown]
# # New Section
